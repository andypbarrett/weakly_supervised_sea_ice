# %% [markdown]
# # **02. Download necessary data**

# %% [markdown]
# This notebook is for downloading multiple files for generating time-series labels of sea ice classification. The purpose of this notebook is to generate combined file of AI4Arctic-similar datasets but using multi-time-series data. Once you download four different types of data (i.e., ice chart (vector), Sentinel-1 SAR (raster), AMSR2 brightness temperature (raster), and ERA5 reanalysis (raster)), you will be able to combine them into a single netCDF file (.nc format).
#
# ## Arctic Ice Chart
# - You can use the ice chart shapefiles (.shp) downloaded from PolarView (www.polarview.aq) and Arctic Ice Logistics Portal (www.icelogistics.info/arctic). Please use the ``DATA01_Download_chart.ipynb`` for detailed instructions of downloading these shapefiles.
#
# ## Sentinel-1 Synthetic aperture radar (SAR) images
# - Sentinel-1 images are downloaded from Google Earth Engine (https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S1_GRD).
# - Original resolution of Sentinel-1 image is 40 m, but we resample them into 120 m for downloading. This parameter can be adjusted in the [**Parameter setting**](#parameter_setting) cell, but please note that there is a maximum requeset size in Google Earth Engine (32 MB) you can download. If the requested array exceeds this request size, an error message may appear.
#     - Bands: HH and HV
#
# ## AMSR2 Passive microwave (PMW) data
# - A corresponding AMSR2 is produced, containing AMSR2 brightness temperatures resampled to the Sentinel-1 geometry. The level-1b AMSR2 product is retrieved from JAXA’s G-Portal (https://gportal.readthedocs.io/en/stable/).
#     - btemp_FFP - brightness temperatures (Tb) from the instrument for frequencies FF = [6.9, 7.3, 10.7, 18.7, 23.8, 36.5, 89.0] and polarisations P = [v, h]
#
# ## ERA5 Atmospheric reanalysis data
# - Following the data architecture of the AI4Arctic dataset, we use the following weather paraeters from ERA5.
#     - u10m_rotated - ERA5 eastward component of the 10m wind rotated to the NSIDC Sea Ice Polar Stereographic North (EPSG 3413).
#     - v10m_rotated - ERA5 northward component of the 10m wind rotated to the NSIDC Sea Ice Polar Stereographic North (EPSG 3413).
#     - t2m - ERA5 2m air temperature.
#     - skt - ERA5 skin temperature.
#     - tcwv - ERA5 total column water vapor.
#     - tclw - ERA5 total column cloud liquid water.

# %% [markdown]
# ## Import functions

# %%
import ee
import geemap
import matplotlib.pyplot as plt
import time

try:        
    # Initialize with your own project - Please specify your own project name.
    ee.Initialize(project = "utsa-spring2024")
except:
# Authenticate
    ee.Authenticate()
    # Initialize with your own project - Please specify your own project name.
    ee.Initialize(project = "utsa-spring2024")

import os
from datetime import datetime
import geopandas as gpd
import numpy as np

import gportal
import json
import os, glob
import requests
from datetime import datetime, timedelta

import cartopy.crs as ccrs
import cartopy.feature as cfeature

import warnings
warnings.filterwarnings("ignore")

# %%
import requests
import geopandas as gpd
from shapely.geometry import Polygon
import geopandas as gpd
import pandas as pd
import rasterio
from rasterio import features
import cdsapi
import xarray as xr

def add_HH(img):
    bands = img.bandNames() # First band ('HH' or 'VV')
    band = ['HH']
    norm = img.select(band).divide(img.select('angle')).rename('HH_norm')
    img2 = img.addBands(norm, overwrite=True) #.select('HH_norm')
    return img2

def add_HV(img):
    bands = img.bandNames() # First band ('HH' or 'VV')
    band = ['HV']
    norm = img.select(band).divide(img.select('angle')).rename('HV_norm')
    img2 = img.addBands(norm, overwrite=True) #.select('HH_norm')
    return img2

def add_coverage(img):    
    tol = 1000
    overlap = img.geometry().intersection(extent, tol)
    ratio = overlap.area(tol).divide(extent.area(tol)) #overlap.area(tol).divide(img.geometry().area(tol))
    return img.set({'coverage_ratio': ratio})
    
def add_area(img):    
    tol = 1000    
    return img.set({'coverage_area': img.geometry().area(tol)})
    
def add_chart_id(gdf):
    
    fields = ['CT', 'CA', 'CB', 'CC', 'CN', 'SA', 'SB', 'SC', 'CD', 'FA', 'FB', 'FC'] #gdf.keys()[3:-6]
    codes = []
    poly_id = []
    N = 0

    for i in range(0, len(gdf)):
        cd = ""
        for f in fields:
            try:
                cd += gdf.loc[i, f] + ";"
            except:
                cd += "-9;"

        gdf.loc[i, "code"] = cd
        
        if cd not in codes:
            codes.append(cd)
            N += 1
            gdf.loc[i, "poly_id"] = N
            poly_id.append(N)
        else:
            idx = np.where(np.array(codes) == cd)[0][0]
            gdf.loc[i, "poly_id"] = poly_id[idx]

        
    return gdf

def get_chart_id(table, unique_id):
    fields = ['poly_id', 'CT', 'CA', 'CB', 'CC', 'CN', 'SA', 'SB', 'SC', 'CD', 'FA', 'FB', 'FC']
    code0 = ""
    for s in fields:
        if s != fields[-1]:
            code0 += s + ";"
        else:
            code0 += s
    codes = [code0]
    for n in unique_id:
        codes.append(str(int(n)) + ";" + table[table["poly_id"] == n].reset_index(drop=True).loc[0, "code"][:-1])
        
    return codes


def download_img(img, proj, pixel_size, extent, out_tif):
    # proj2 = ee.Projection(proj).atScale(pixel_size)  # example: 1 km resolution
    # img_reproj = img.reproject(proj2)

    url = img.getDownloadURL({
        'scale': pixel_size,
        'crs': proj,
        'region': extent,
        'format': 'GEO_TIFF'
    })
    
    # Download file
    response = requests.get(url)
    with open(out_tif, "wb") as f:
        f.write(response.content)
    
    print(f"Saved to {out_tif}")


def rectangle_to_gdf(coords, crs):
    """
    coords: list of 5 (x, y) or (lon, lat) tuples
    crs: CRS string, e.g., 'EPSG:4326' or 'EPSG:3408'
    """
    poly = Polygon(coords)
    return gpd.GeoDataFrame({"id": [1]}, geometry=[poly], crs=crs)

def save_chart_tif(ref_tif, chart_tif, chart2):
    # rst_fn = "output.tif"
    rst = rasterio.open(ref_tif)
    ref_img = rst.read(1)
    meta = rst.meta.copy()
    meta.update(compress='lzw')
    
    with rasterio.open(chart_tif, 'w+', **meta) as out:
        out_arr = out.read(1)
    
        # this is where we create a generator of geom, value pairs to use in rasterizing
        shapes = ((geom,value) for geom, value in zip(chart2.geometry, chart2.poly_id))
    
        burned = features.rasterize(shapes=shapes, fill=0, out=out_arr, transform=out.transform)
        out.write_band(1, burned)
        print(f"Saved to {chart_tif}")

def get_extent(center, distance, proj):
    # center = [lon, lat]
    geometry = ee.Geometry.Point(center[0], center[1])    
    # if proj == "EPSG:3857":
    #     extent = geometry.buffer(distance = distance).bounds()
    #     dp = appropriate_resolution(center, pixel_size)
    # else:
    extent = geometry.buffer(distance = distance, proj = proj).bounds(proj = proj)
    
    return extent


def get_S1_array(center, t1, t2, pixel_size = 60, distance = 100000, proj = "EPSG:3409"):
    # proj - EPSG:3409 (EASE South); EPSG:3976 (NSIDC south polar stereo); EPSG:3857 (Web Mercator)

    geometry = ee.Geometry.Point(center[0], center[1])
    
    if proj == "EPSG:3857":
        extent = geometry.buffer(distance = distance).bounds()
        dp = appropriate_resolution(center, pixel_size)
    else:
        extent = geometry.buffer(distance = distance, proj = proj).bounds(proj = proj)
        dp = pixel_size

def empty(*args, **kwargs): return ""

def retrieve_hourly_ERA5_bbox(years, months, days, hours, bbox, object):
    c = cdsapi.Client(quiet=True, wait_until_complete=False, delete=True, progress=False, warning_callback = empty, sleep_max=10)
    # dataset to read
    dataset = 'reanalysis-era5-single-levels'
    # flag to download data
    # download_flag = False
    variables = [
        '10m_u_component_of_wind', '10m_v_component_of_wind', '2m_temperature', 'skin_temperature', "total_column_cloud_liquid_water", "total_column_water_vapour"
        # 'sea_ice_cover', '2m_temperature', 'sea_ice_cover', 'surface_pressure', 'skin_temperature', 'instantaneous_10m_wind_gust', 
    ]

    # u10m_rotated, v10m_rotated, t2m, skt, tcwv, tclw -> In the AI4Arctic Dataset

    # bbox: [north, west, south, east]
    params = {
        'format': 'netcdf',
        'product_type': 'reanalysis',
        'variable': variables,
        'year': years,
        'month': months,
        'day': days,
        'time': hours,
        'grid': [0.2, 0.1],
        'area': [bbox[0], bbox[1], bbox[2], bbox[3]]
        }

    # retrieves the path to the file
    # target = 'download.nc'
    if object == None:
        print("Please provide the correct file name!")
        # fl = c.retrieve(dataset, params).download()
        # ds = xr.open_dataset(fl)
        # return ds, fl
    else:
        c.retrieve(dataset, params, object)

def rotate_vector(u, v, lon, ref_lon = 0, hemi = "NH"):
    # Latitude & longitude grid to polar grid
    # ref_lon: longitude of center bottom
    if hemi == "NH":
        angle = (lon-ref_lon)*np.pi/180 # rotation angle (radian)
    else:
        angle = -(lon-ref_lon)*np.pi/180
    u2 = u*np.cos(angle) - v*np.sin(angle)
    v2 = u*np.sin(angle) + v*np.cos(angle)
    return u2, v2

def hour_rounder(t):
    return (t.replace(second=0, microsecond=0, minute=0, hour=t.hour)
               +timedelta(hours=t.minute//30))

def get_intersection(gdf1, gdf2, proj):
    # Calculate intersection area between two polygons
    intersection = gpd.overlay(gdf1.to_crs(proj), gdf2.to_crs(proj), how="intersection")
    
    intersection["overlap_area"] = intersection.geometry.area
    total_overlap_area = intersection["overlap_area"].sum()
    area1 = gdf1.geometry.area.sum()
    percent_overlap = (total_overlap_area / area1) * 100
    return percent_overlap.item()

def get_overlap_chart(lat0, lon0, extent_gdf, folder, chart_folder, startdate, enddate, proj):
    chart_ids = []
    dfc = pd.DataFrame()
    i = 0
    
    for agency in os.listdir(chart_folder): #, "CIS", "NOAA", "METNO", "DMI"]: # What ice centers you are interested in?
        folders = [f for f in os.listdir(chart_folder + agency) if f[-4:] != ".zip"]   
        
        for f in folders:
            chart_id = f.split("_")[1]
            date = datetime.strptime(f.split("_")[2], "%Y%m%d")
            
            if (chart_id not in chart_ids) & (date >= datetime.strptime(startdate, "%Y-%m-%d")) & (date <= datetime.strptime(enddate, "%Y-%m-%d")):
                chart_ids.append(chart_id)
                file = glob.glob(os.path.join(chart_folder + agency, f) + "\\*.shp")[0]
                polygon = gpd.read_file(file)
                r = get_intersection(extent_gdf, polygon, proj)
                if r > 50:
                    dfc.loc[i, "agency"] = agency
                    dfc.loc[i, "chart_id"] = chart_id
                    dfc.loc[i, "lat"] = lat0
                    dfc.loc[i, "lon"] = lon0
                    dfc.loc[i, "radius"] = distance
                    dfc.loc[i, "folder"] = chart_folder + agency
                    dfc.loc[i, "first_date"] = date.strftime("%Y%m%d")
                    i += 1
    
    # Make folder to download ice chart tiff files
    subfolder = folder + f"Chart\\{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}"
    if not os.path.exists(subfolder):
        os.makedirs(subfolder)
    dfc.to_csv(f"{subfolder}\\Chart_list_{str(int(lat0)).zfill(2)}_{str(int(lon0))}.csv")

    return dfc

def filter_dfc(dfc):
    if 'DMI' in np.unique(dfc['agency']):
        dfc = dfc[dfc['agency'] == "DMI"].reset_index(drop = True).loc[:1, :]
    elif 'NOAA' in np.unique(dfc['agency']):
        dfc = dfc[dfc['agency'] == "NOAA"].reset_index(drop = True)
    else:
        dfc = dfc[dfc['agency'] == "NIC"].reset_index(drop = True)
    return dfc

def read_tif(file):
    with rasterio.open(file) as rst:
        array = rst.read(1)
        array[array == 0] = np.nan
    return array

def unique_value(lists):
    list_unique = []
    for item in lists:
        if item not in list_unique:
            list_unique.append(item)
    return list_unique

def find_nearest_chart(S1_file, chart_list, dsec = 15):
    # S1_time = datetime.strptime(os.path.basename(S1_file).split("_")[-1][:-4], "%Y%m%dT%H%M%S")
    S1_time = datetime.strptime(S1_file, "%Y%m%dT%H%M%S")
    for c in chart_list:
        chart_time = datetime.strptime(os.path.basename(c).split("_")[2], "%Y%m%d")
        if abs(S1_time - chart_time).days < dsec:
            target = c
            dsec = abs(S1_time - chart_time).days
    return target

def grid_swath_data(vals, lons, lats, areadef, radius=20e3, nanval=0, label=None):
    # Grid the data to an areadef

    swathdef = get_pyresample_swathdef(lons=lons, lats=lats)

    resampler = NumpyBilinearResampler(swathdef, areadef, radius)

    if label is not None:
        print(f'resampling swath data ({label})...', end='', flush=True)
    with warnings.catch_warnings(record=True) as warning_list:
        gridded = resampler.resample(vals).astype(np.float32)

        for warning in warning_list:
            message = warning.message

            # Ignore proj messages about using CRS codes
            if isinstance(message, UserWarning) and 'converting to a PROJ string' in str(message):
                pass
            else:
                print(f'warning: {message}')

    if label is not None:
        print('done', flush=True)

    # Set NaN values
    if nanval is not None:
        gridded[gridded == nanval] = np.nan

    return gridded

def get_pyresample_area_def(gridid):
    """Return the pyresample module's AreaDefinition for a specified grid"""
    try:
        assert gridid in GRIDID_AREADEFS.keys()
    except AssertionError:
        raise ValueError(f'No AreaDefinition information for: {gridid}')

    gridid_area_def = GRIDID_AREADEFS[gridid]
    area_def = AreaDefinition(
        gridid_area_def['area_id'],
        gridid_area_def['description'],
        gridid_area_def['proj_id'],
        gridid_area_def['projection'],
        gridid_area_def['width'],
        gridid_area_def['height'],
        gridid_area_def['area_extent'],
    )

    return area_def
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# <a id="parameter_setting"></a>
# ## Parameter Setting

# %%
##### PARAMETERS ####################################################
# Directory to save the output files
folder = 'C:\\Users\\yoko2261\\OneDrive - UCB-O365\\CAIG\\TS\\'
global folder
# Directory of ice chart shapefiles
chart_folder = "C:\\Users\\yoko2261\\OneDrive - UCB-O365\\CAIG\\Ice_chart\\"

proj = 'EPSG:3413' #'EPSG:3408'
pixel_size = 160

# Earliest date: 2024/08/10
startdate = '2025-01-01' 
enddate = '2026-01-01'

lat0 = 72 #66 #lats[order]
lon0 = -60 #58 #lons[order]
center = [lon0, lat0]
distance = pixel_size * 1024 - pixel_size/2 #120000 # Radius of extent from the center (lon0, lat0)
extent = get_extent(center, distance, proj)
extent_gdf = geemap.ee_to_gdf(ee.FeatureCollection(extent.transform(proj='EPSG:4326', maxError=10))).to_crs(proj)

# dfc = get_overlap_chart(lat0, lon0, extent_gdf, folder, chart_folder, startdate, enddate, proj)
# dfc
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## See the distribution of ice charts

# %%
import matplotlib.ticker as mticker
import matplotlib.patches as mpatches

chart_ids = []
fig = plt.figure(figsize=(7, 7))
ax = plt.axes(projection=ccrs.NorthPolarStereo(central_longitude=-45, true_scale_latitude=70))

land = cfeature.NaturalEarthFeature(
    category="physical",
    name="land",
    scale="50m",
    facecolor="lightgray"
)

coastline = cfeature.NaturalEarthFeature(
    category="physical",
    name="coastline",
    scale="50m",
    facecolor="none"
)

patch = {}

colors = ["b", "r", "g", "orange", "gray"]
for i, agency in enumerate(os.listdir(chart_folder)): #, "CIS", "NOAA", "METNO", "DMI"]: # What ice centers you are interested in?
    folders = [f for f in os.listdir(chart_folder + agency) if f[-4:] != ".zip"]   

    patch[agency] = mpatches.Patch(
        facecolor=colors[i],
        edgecolor="black",
        alpha = 0.3,
        label=agency
    )
    
    for f in folders:
        chart_id = f.split("_")[1]
        date = datetime.strptime(f.split("_")[2], "%Y%m%d")
        
        if (chart_id not in chart_ids):
            chart_ids.append(chart_id)
            file = glob.glob(os.path.join(chart_folder + agency, f) + "\\*.shp")[0]
            polygon = gpd.read_file(file).to_crs('EPSG:3413')
            polygon.plot(ax = ax, alpha = 0.3, color = colors[i])

# # Set extent (lon_min, lon_max, lat_min, lat_max)
ax.set_extent([-180, 180, 50, 90], crs=ccrs.PlateCarree())

lats = [ 73,  70,  66,  75,  71,    72,   75,  78,  75,  72, 81]
lons = [-60, -58, -58, -72, -142, -154, -142, -10, -12, -15, -5]
for k in range(0, len(lats)):
    lat0 = lats[k] #66 #lats[order]
    lon0 = lons[k] #58 #lons[order]
    center = [lon0, lat0]
    extent = get_extent(center, distance, proj)
    extent_gdf = geemap.ee_to_gdf(ee.FeatureCollection(extent.transform(proj='EPSG:4326', maxError=10))).to_crs(proj)
    extent_gdf.to_crs('EPSG:3413').boundary.plot(ax = ax, color = "black", lw = 2, zorder = 5)

ax.legend(
        handles=[patch[p] for p in patch.keys()],
        loc="upper right",
        frameon=False,
        fontsize = 15
    )

# Add background features
ax.add_feature(coastline, linewidth=1)
ax.add_feature(land, facecolor="white")
# ax.gridlines(draw_labels=False, linestyle="--", alpha=0.5)

gl = ax.gridlines(
    crs=ccrs.PlateCarree(),
    draw_labels=False,
    linewidth=0.6,
    color="gray",
    alpha=0.6,
    linestyle="--"
)

# Longitude lines every 30°
gl.xlocator = mticker.FixedLocator(range(-180, 181, 20))

# (Optional) Latitude lines every 10°
gl.ylocator = mticker.FixedLocator(range(50, 91, 5))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Download datasets (S1, AMSR2, EREA5)

# %%
from scipy.ndimage import zoom
from pyresample import geometry, kd_tree, bilinear
from netCDF4 import Dataset
from pyresample import geometry, kd_tree
from pyresample.geometry import AreaDefinition, SwathDefinition
from pyresample.bilinear import NumpyBilinearResampler

def combine_to_netcdf(lat0, lon0, time0, sar_id, amsr_files, era5_file, chart_id, proj = 'EPSG:3413', scale = 4):

    nc_dir = folder + f"NetCDF\\{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}"
    if not os.path.exists(nc_dir):
        os.makedirs(nc_dir)
    
    nc_name = f"{nc_dir}\\{sar_id}.nc"
    
    with Dataset(nc_name, "w", format="NETCDF4") as nc:
        
        subfolder = f"{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}"
        chart_list = glob.glob(folder + f"Chart\\{subfolder}\\{chart_id}_{time0[:4]}*.tif")
        
        chart_file = find_nearest_chart(time0, chart_list)
        array_chart = zoom(read_tif(chart_file), zoom=scale, order=0)
    
        table = pd.read_csv(chart_file.replace(".tif", ".csv"), index_col = 0)
        unique_id = np.unique(table['poly_id'])
        codes = get_chart_id(table, unique_id)
        
        S1_hh = f"{folder}\\S1\\{subfolder}\\S1_HH_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}_{time0}.tif"
        hh = zoom(read_tif(S1_hh), zoom=scale, order=1)
    
        S1_hv = f"{folder}\\S1\\{subfolder}\\S1_HV_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}_{time0}.tif"
        hv = zoom(read_tif(S1_hv), zoom=scale, order=1)
    
        S1_angle = f"{folder}\\S1\\{subfolder}\\S1_angle_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}_{time0}.tif"
        angle = zoom(read_tif(S1_angle), zoom=scale, order=1)
        
        S1_x = f"{folder}\\S1\\{subfolder}\\S1_x_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}.tif"
        xx = zoom(read_tif(S1_x), zoom=scale, order=1)
    
        S1_y = f"{folder}\\S1\\{subfolder}\\S1_y_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}.tif"
        yy = zoom(read_tif(S1_y), zoom=scale, order=1)  
    
        x_min = np.nanmin(xx)
        x_max = np.nanmax(xx)
        y_min = np.nanmin(yy)
        y_max = np.nanmax(yy)

        nxs, nys = xx.shape
        nxp, nyp = 256, 256

        areas_def = geometry.AreaDefinition(
            area_id=proj,
            description="Arctic Polar Stereographic",
            proj_id=proj,
            projection=proj.upper(),
            width=nxs,
            height=nys,
            area_extent=(x_min, y_min, x_max, y_max)
        )
    
        areap_def = geometry.AreaDefinition(
            area_id=proj,
            description="Arctic Polar Stereographic",
            proj_id=proj,
            projection=proj.upper(),
            width=nxp,
            height=nyp,
            area_extent=(x_min, y_min, x_max, y_max)
        )

        ###### X-Y DIMENSION DEFINITION (X, Y, LAT, LON) ###################################
        # S1 SAR grid
        nc.createDimension("y", xx.shape[0])
        nc.createDimension("x", xx.shape[1])
    
        # AMSR & ERA5 grid
        nc.createDimension("yp", nyp)
        nc.createDimension("xp", nxp)

        ys = nc.createVariable("y", "f4", ("y",))
        xs = nc.createVariable("x", "f4", ("x",))
        xs[:] = xx[0, :]
        ys[:] = yy[:, 0]
    
        yp = nc.createVariable("yp", "f4", ("yp",))
        xp = nc.createVariable("xp", "f4", ("xp",))
        yp[:] = areap_def.projection_y_coords
        xp[:] = areap_def.projection_x_coords

        lat = nc.createVariable("latitude", "f4", ("y", "x"), zlib=True, fill_value=np.nan)
        lon = nc.createVariable("longitude", "f4", ("y", "x"), zlib=True, fill_value=np.nan)
        lon[:, :] = areas_def.get_lonlats()[0]
        lat[:, :] = areas_def.get_lonlats()[1]

        latp = nc.createVariable("latitude_p", "f4", ("yp", "xp"), zlib=True, fill_value=np.nan)
        lonp = nc.createVariable("longitude_p", "f4", ("yp", "xp"), zlib=True, fill_value=np.nan)
        lonp[:, :] = areap_def.get_lonlats()[0]
        latp[:, :] = areap_def.get_lonlats()[1]

        ##### WRITE CHART DATA ####################################################
        polygon_icechart = nc.createVariable("polygon_icechart", "f4", ("y", "x"), zlib=True, fill_value=np.nan)
        polygon_icechart[:, :] = array_chart
        nc.ice_chart_polygon_code = np.array(codes, dtype="S")
        polygon_icechart.description = "Polygon icechart - the polygon ids are gridded in native Sentinel-1 SAR geometry- and resolution"
        polygon_icechart.icechart_id = os.path.basename(chart_file)

        ##### WRITE SAR DATA ####################################################
        sar_grid_hh = nc.createVariable("sar_grid_hh", "f4", ("y", "x"), zlib=True, fill_value=np.nan)
        sar_grid_hh[:, :] = hh
        sar_grid_hh.polarisation = "HH"
        sar_grid_hh.upstream_id = sar_id
        sar_grid_hh.description = "Sigma0 in dB"
        sar_grid_hh.min = np.nanmin(hh)
        sar_grid_hh.max = np.nanmax(hh)

        sar_grid_hv = nc.createVariable("sar_grid_hv", "f4", ("y", "x"), zlib=True, fill_value=np.nan)
        sar_grid_hv[:, :] = hv
        sar_grid_hv.polarisation = "HV"
        sar_grid_hv.upstream_id = sar_id
        sar_grid_hv.description = "Sigma0 in dB"
        sar_grid_hv.min = np.nanmin(hv)
        sar_grid_hv.max = np.nanmax(hv)
        
        sar_grid_angle = nc.createVariable("sar_grid_incidenceangle", "f4", ("y", "x"), zlib=True, fill_value=np.nan)
        sar_grid_angle[:, :] = angle
    
        ##### AMSR2 data conversion ##############################################

        # Find AMSR2 file with the lagest coverage
        amsr_cover = 0
        amsr_target = amsr_files[0]
        for amsr_file in amsr_files:
            with xr.open_dataset(amsr_file) as ds_amsr:        
                lat_varname = 'Latitude of Observation Point for 89A'
                lon_varname = 'Longitude of Observation Point for 89A'
                lat_amsr = np.array(ds_amsr.variables[lat_varname])[:, ::2]
                lon_amsr = np.array(ds_amsr.variables[lon_varname])[:, ::2]
            
                swath_amsr = geometry.SwathDefinition(lons=lon_amsr, lats=lat_amsr)
                resampler = NumpyBilinearResampler(swath_amsr, areap_def, 50000)
                val_varname = f"Brightness Temperature (res06,89.0GHz,H)"
                val = np.array(ds_amsr.variables[val_varname])
                gridded = resampler.resample(val)
                gridded[gridded == 0] = np.nan
                ac = np.count_nonzero(~np.isnan(gridded))/(nxp * nyp)
                if ac > amsr_cover:
                    amsr_cover = ac
                    amsr_target = amsr_file
                    # print(amsr_cover, amsr_target)

        # Apply the maximum-coverage amsr file (amsr_target)
        with xr.open_dataset(amsr_target) as ds_amsr:
            lat_varname = 'Latitude of Observation Point for 89A'
            lon_varname = 'Longitude of Observation Point for 89A'
            lat_amsr = np.array(ds_amsr.variables[lat_varname])[:, ::2]
            lon_amsr = np.array(ds_amsr.variables[lon_varname])[:, ::2]
        
            swath_amsr = geometry.SwathDefinition(lons=lon_amsr, lats=lat_amsr)
            resampler = NumpyBilinearResampler(swath_amsr, areap_def, 50000)
            
            channels = ["6.9", "7.3", "10.7", "18.7", "23.8", "36.5", "89.0"]
            for cha in channels:
                for pol in ["V", "H"]:
                    val_varname = f"Brightness Temperature (res06,{cha}GHz,{pol})"
                    val = np.array(ds_amsr.variables[val_varname])
                    gridded = resampler.resample(val) #.astype(np.float32)
                    gridded[gridded == 0] = np.nan
    
                    amsr_grid = nc.createVariable("btemp_" + cha.replace(".", "_") + pol.lower(), "f4", ("yp", "xp"), zlib=True, fill_value=np.nan)
                    amsr_grid[:, :] = gridded
                    amsr_grid.AMSR2_swaths = os.path.basename(amsr_target)
                    amsr_grid.min = np.nanmin(gridded)
                    amsr_grid.max = np.nanmax(gridded)
                    amsr_grid.description = f"Brightness temperature in K at {cha}GHz. Polarization: {pol}."
    
        ##### ERA5 data conversion ################################################
        with xr.open_dataset(era5_file) as ds_era:
            lon, lat = np.meshgrid(np.array(ds_era.variables["longitude"]), np.array(ds_era.variables["latitude"]))
            swath_era = geometry.SwathDefinition(lons=lon, lats=lat)
            resampler = NumpyBilinearResampler(swath_era, areap_def, 100000)

            if proj == "EPSG:3413":
                ref_lon = -45
            else:
                ref_lon = 0
        
            u10 = np.array(ds_era.variables['u10'])
            v10 = np.array(ds_era.variables['v10'])        
            u10r, v10r = rotate_vector(u10, v10, lon, ref_lon = ref_lon)
            u10r_grid = resampler.resample(u10r)
            v10r_grid = resampler.resample(v10r)
            
            era_grid_u = nc.createVariable("u10m_rotated", "f4", ("yp", "xp"), zlib=True, fill_value=np.nan)
            era_grid_u[:, :] = u10r_grid
            era_grid_u.units = ds_era['u10'].units
            era_grid_u.long_name = ds_era['u10'].long_name
    
            era_grid_v = nc.createVariable("v10m_rotated", "f4", ("yp", "xp"), zlib=True, fill_value=np.nan)
            era_grid_v[:, :] = v10r_grid
            era_grid_v.units = ds_era['v10'].units
            era_grid_v.long_name = ds_era['v10'].long_name
            # ac = np.count_nonzero(~np.isnan(v10r_grid))/(nxp * nyp)
            # print("ERA5: ", ac)
    
            for field in ["t2m", "skt", "tcwv", "tclw"]:
                val = np.array(ds_era.variables[field])
                gridded = resampler.resample(val)
                era_grid = nc.createVariable(field, "f4", ("yp", "xp"), zlib=True, fill_value=np.nan)
                era_grid[:, :] = gridded
                era_grid.units = ds_era[field].units
                era_grid.long_name = ds_era[field].long_name
                
    print("DONE ==>> ", nc_name, "\n")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#####################################################################

# lats = [ 73,  70,  66,  75,  71,   72,   72,   74,  78,  75,  72,  81]
# lons = [-60, -58, -58, -72, -140, -148, -156, -142, -10, -12, -15, -5]

lats = [ 73,  70,  66,  75,  71,    72,   75,  78,  75,  72, 81]
lons = [-60, -58, -58, -72, -142, -154, -142, -10, -12, -15, -5]

platform = "A"

for k in range(9, len(lats)):

    ##### Latitude and longitude initialization #############################
    lat0 = lats[k] #66 #lats[order]
    lon0 = lons[k] #58 #lons[order]
    center = [lon0, lat0]
    extent = get_extent(center, distance, proj)

    coord = np.array(extent.transform(proj='EPSG:4326', maxError=10).getInfo()['coordinates'][0])
    lon_max, lat_max = np.nanmax(coord, axis = 0)
    lon_min, lat_min = np.nanmin(coord, axis = 0)

    # Create polygon from EPSG:3413 coordinates
    coords = extent.getInfo()['coordinates']
    coords2 = [(xys[0], xys[1]) for xys in coords[0]]
    
    # Build GeoDataFrame
    extent_gdf = rectangle_to_gdf(coords2, proj)
    dfc = get_overlap_chart(lat0, lon0, extent_gdf, folder, chart_folder, startdate, enddate, proj)
    dfc = filter_dfc(dfc)
    
    source = "COPERNICUS/S1_GRD"
    S1 = ee.ImageCollection(source)\
      .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'HH'))\
      .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'HV'))\
      .filter(ee.Filter.eq('platform_number', platform))\
      .filterDate(startdate, enddate)\
      .filterBounds(extent);
    ##########################################################################
    
    # S1 = S1.map(add_HH)
    S1 = S1.map(add_coverage).map(add_area)
    
    S1 = S1.filter(ee.Filter.gt('coverage_ratio', 0.75)) #.filter(ee.Filter.gt('coverage_area', 8e10))
    num = S1.size().getInfo()
    print(f"{lat0}, {lon0}; {startdate} - {enddate}; Number of S1 images: ", num)
    # print(S1.aggregate_array("coverage_ratio").getInfo())
    
    files = S1.aggregate_array("system:id").getInfo() 
    coverages = S1.aggregate_array("coverage_ratio").getInfo() 
    
    first = True
    df = pd.DataFrame({'S1_id': files, 'coverage_ratio': coverages})
    df['lat'] = lat0
    df['lon'] = lon0
    df['proj'] = proj
    df.to_csv(folder + f"S1\\S1{platform}_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}.csv")
    
    for f in files[:]:
        time0 = f.split("_")[-5]
        date0 = time0[:8]
        
        print(f, date0)
        
        ### ====== Sentinel-1 images =====
        img = ee.Image(f).setDefaultProjection(proj)
    
        band_coord = ee.Image.pixelCoordinates(proj)
        img = img.addBands(band_coord)
        
        # img_hh = img.select('HH').clip(extent)
        # img_hv = img.select('HV').clip(extent)
        # img_angle = img.select('angle').clip(extent)
        # img_xx = img.select('x').clip(extent)
        # img_yy = img.select('y').clip(extent)
    
        if first:
            bands = ['HH', 'HV', 'angle', 'x', 'y']
            first = False
        else:
            bands = ['HH', 'HV', 'angle']
    
        # Make folder to download ice chart tiff files
        subfolder = folder + f"S1\\{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}"
        if not os.path.exists(subfolder):
            os.makedirs(subfolder)
            
        for band in bands:
            img2 = img.select(band).clip(extent)
            if band in ['x', 'y']:
                out_tif = f"{subfolder}\\S1_{band}_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}.tif"
            else:
                out_tif = f"{subfolder}\\S1_{band}_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}_{time0}.tif"
                
            if os.path.exists(out_tif) == False:
                # geemap.ee_to_geotiff(img2, out_tif, bands =  resolution = pixel_size, crs = proj, quiet = True)
                # geemap.ee_export_image(img2, filename=out_tif, scale=pixel_size, region=extent, crs = proj, file_per_band=False)
                download_img(img2, proj, pixel_size, extent, out_tif)
    
        ### ===== Ice Chart =====
        for i in range(0, len(dfc)):
            charts = os.listdir(dfc.loc[i, "folder"])
            for chart in charts:
                if (abs(datetime.strptime(chart.split("_")[2], "%Y%m%d") - datetime.strptime(date0, "%Y%m%d")).days < 7) & (chart.split("_")[1] == dfc.loc[i, "chart_id"]):
                    chartname = glob.glob(os.path.join(dfc.loc[i, "folder"], chart) + "\\*.shp")[0]
                    polygon = gpd.read_file(chartname).to_crs(proj)
                    polygon = add_chart_id(polygon)
                    # chart2 = chart.clip(extent_gdf).reset_index(drop = True)
            
                    # Make folder to download ice chart tiff files
                    subfolder = folder + f"Chart\\{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}"
                    if not os.path.exists(subfolder):
                        os.makedirs(subfolder)
                    
                    chart_tif = f"{subfolder}\\{chart}_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}.tif"
                    if os.path.exists(chart_tif) == False:
                        save_chart_tif(out_tif, chart_tif, polygon)        
                        polygon.to_csv(chart_tif.replace(".tif", ".csv"))
                    chart_id = chart[:-9]
        
        ### ===== AMSR =====
        # [min lon, min lat, max lon, max lat]
        bbox_amsr=[lon_min-1, lat_min-0.5, lon_max+1, lat_max+0.5] #[lon0-2, lat0-1, lon0+2, lat0+1]
        amsr_cnt = 0
        dh = 3
        
        while amsr_cnt < 2:
            start_time = datetime.strptime(f"{time0}", "%Y%m%dT%H%M%S") - timedelta(seconds = 3600*dh)
            end_time = datetime.strptime(f"{time0}", "%Y%m%dT%H%M%S") + timedelta(seconds = 3600*dh)
            res = gportal.search(
                dataset_ids=['11001002'], # 'L2-Sea Ice Concentration（SIC)': ['11002013', '11002006']; 'L1R-Brightness temperature（TB）': ['11001002'] L1R Brightness temp: ['11001002'],  # l1r - see gportal.datasets()
                start_time=start_time,
                end_time=end_time,
                bbox=bbox_amsr
            )
        
            amsr_cnt = res.matched()
            print(f"Matched for {start_time.strftime('%Y-%m-%d %H:%M:%S')} to {end_time.strftime('%Y-%m-%d %H:%M:%S')}: {res.matched()}")    
            dh += 3
    
        products = res.products()
        scratch = folder + "AMSR\\"

        amsr_files = []
        for product in res.products():
            # print(product.data_url)    
        
            out_file = os.path.join(scratch, product.id + ".nc")
            amsr_files.append(out_file)
            if os.path.exists(out_file) and os.path.getsize(out_file) > 0:
                print(f"file {out_file} exists, skipping download")
                # return out_file
            else:
                response = requests.get(product.data_url)
            
                os.makedirs(scratch, exist_ok=True)
                
                if response.status_code == 200:
                    with open(out_file, 'wb') as file:
                        file.write(response.content)
                    print(f'AMSR ({out_file}) downloaded successfully')
    
        ### ===== ERA5 =====
        # [90, -180, 0, 180] [north, west, south, east]
        bbox_era5=[lat_max+1, lon_min-2, lat_min-1, lon_max+2] #[lon_min-1, lat_max+0.5, lon_max+1, lat_min-0.5]
        t = hour_rounder(datetime.strptime(f"{time0}", "%Y%m%dT%H%M%S"))
        years = [f"{str(t.year).zfill(4)}"]
        months = [f"{str(t.month).zfill(2)}"]
        days = [f"{str(t.day).zfill(2)}"]
        hours = [f"{str(t.hour).zfill(2)}:00"]
    
        subfolder = folder + f"ERA5\\{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}"
        if not os.path.exists(subfolder):
            os.makedirs(subfolder)
        file_era5 = f"{subfolder}\\ERA5_{time0}_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}.nc"
        if os.path.exists(file_era5):
            print(f"ERA5 skipped - {file_era5}")
        else:
            retrieve_hourly_ERA5_bbox(years, months, days, hours, bbox_era5, file_era5)
            print(f"ERA5 downloaded - {file_era5}")

        #### COMBINE to NC file #####            
        sar_id = os.path.basename(f)
        combine_to_netcdf(lat0, lon0, time0, sar_id, amsr_files, file_era5, chart_id)
    
    print("================================================================")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 72, -15; 2025-01-01 - 2026-01-01; Number of S1 images:  60
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250103T075600_20250103T075700_057277_070BE6_112B 20250103
# Matched for 2025-01-03 04:56:00 to 2025-01-03 10:56:00: 5
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501030604_007D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501030743_023D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501030922_039D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501030832_023A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501031011_039A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 skipped - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250103T075600_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250103T075600_20250103T075700_057277_070BE6_112B.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250106T180353_20250106T180453_057327_070DE4_8D08 20250106
# Matched for 2025-01-06 15:03:53 to 2025-01-06 21:03:53: 0
# Matched for 2025-01-06 12:03:53 to 2025-01-07 00:03:53: 2
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501061221_060A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501061400_076A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 skipped - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250106T180353_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250106T180353_20250106T180453_057327_070DE4_8D08.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250115T075559_20250115T075659_057452_0712D0_5B90 20250115
# Matched for 2025-01-15 04:55:59 to 2025-01-15 10:55:59: 5
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501150628_011D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501150807_027D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501150946_043D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501150857_027A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501151036_043A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 skipped - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250115T075559_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250115T075559_20250115T075659_057452_0712D0_5B90.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250118T180343_20250118T180443_057502_0714D4_82E3 20250118
# Matched for 2025-01-18 15:03:43 to 2025-01-18 21:03:43: 0
# Matched for 2025-01-18 12:03:43 to 2025-01-19 00:03:43: 1
# Matched for 2025-01-18 09:03:43 to 2025-01-19 03:03:43: 5
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501181017_048D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501180927_032A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501181106_048A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501181245_064A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501190246_208D_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 skipped - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250118T180343_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250118T180343_20250118T180443_057502_0714D4_82E3.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250127T075558_20250127T075658_057627_0719CA_F9C3 20250127
# Matched for 2025-01-27 04:55:58 to 2025-01-27 10:55:58: 5
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501270514_232D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501270653_015D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501270832_031D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501270921_031A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501271011_047D_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 skipped - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250127T075558_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250127T075558_20250127T075658_057627_0719CA_F9C3.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250130T180351_20250130T180451_057677_071BC1_B802 20250130
# Matched for 2025-01-30 15:03:51 to 2025-01-30 21:03:51: 0
# Matched for 2025-01-30 12:03:51 to 2025-01-31 00:03:51: 1
# Matched for 2025-01-30 09:03:51 to 2025-01-31 03:03:51: 3
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501300952_036A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501301131_052A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202501301310_068A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 skipped - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250130T180351_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250130T180351_20250130T180451_057677_071BC1_B802.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250208T075558_20250208T075658_057802_0720B1_50C4 20250208
# Matched for 2025-02-08 04:55:58 to 2025-02-08 10:55:58: 4
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502080538_003D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502080717_019D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502080856_035D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502080945_035A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 skipped - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250208T075558_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250208T075558_20250208T075658_057802_0720B1_50C4.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250220T075557_20250220T075657_057977_0727C8_6252 20250220
# Matched for 2025-02-20 04:55:57 to 2025-02-20 10:55:57: 5
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502200602_007D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502200741_023D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502200920_039D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502200830_023A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502201009_039A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 skipped - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250220T075557_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250220T075557_20250220T075657_057977_0727C8_6252.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250223T180351_20250223T180451_058027_0729E0_3BB0 20250223
# Matched for 2025-02-23 15:03:51 to 2025-02-23 21:03:51: 0
# Matched for 2025-02-23 12:03:51 to 2025-02-24 00:03:51: 2
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502231219_060A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502231358_076A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 skipped - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250223T180351_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250223T180351_20250223T180451_058027_0729E0_3BB0.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250228T181146_20250228T181246_058100_072CD2_8E30 20250228
# Matched for 2025-02-28 15:11:46 to 2025-02-28 21:11:46: 0
# Matched for 2025-02-28 12:11:46 to 2025-03-01 00:11:46: 1
# Matched for 2025-02-28 09:11:46 to 2025-03-01 03:11:46: 5
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502280920_031A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502281009_047D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502281059_047A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202502281237_063A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503010238_207D_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 skipped - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250228T181146_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250228T181146_20250228T181246_058100_072CD2_8E30.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250304T075557_20250304T075657_058152_072EF7_1E4A 20250304
# Matched for 2025-03-04 04:55:57 to 2025-03-04 10:55:57: 5
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503040627_011D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503040806_027D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503040855_027A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503040944_043D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503041034_043A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 skipped - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250304T075557_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250304T075557_20250304T075657_058152_072EF7_1E4A.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250307T180351_20250307T180451_058202_073109_F925 20250307
# Matched for 2025-03-07 15:03:51 to 2025-03-07 21:03:51: 0
# Matched for 2025-03-07 12:03:51 to 2025-03-08 00:03:51: 1
# Matched for 2025-03-07 09:03:51 to 2025-03-08 03:03:51: 5
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503070926_032A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503071015_048D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503071105_048A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503071244_064A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503080244_208D_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 skipped - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250307T180351_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250307T180351_20250307T180451_058202_073109_F925.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250316T075557_20250316T075657_058327_0735EF_05ED 20250316
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HH_72_-15_20250316T075557.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HV_72_-15_20250316T075557.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_angle_72_-15_20250316T075557.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\Chart\72_-15\DMI_1302_20250319_72_-15.tif
# Matched for 2025-03-16 04:55:57 to 2025-03-16 10:55:57: 5
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503160512_232D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503160651_015D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503160830_031D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503161009_047D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503160919_031A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 downloaded - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250316T075557_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250316T075557_20250316T075657_058327_0735EF_05ED.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250319T180351_20250319T180451_058377_0737EB_57CA 20250319
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HH_72_-15_20250319T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HV_72_-15_20250319T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_angle_72_-15_20250319T180351.tif
# Matched for 2025-03-19 15:03:51 to 2025-03-19 21:03:51: 0
# Matched for 2025-03-19 12:03:51 to 2025-03-20 00:03:51: 1
# Matched for 2025-03-19 09:03:51 to 2025-03-20 03:03:51: 3
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503190950_036A_L1SGRTBR_2220220.nc) downloaded successfully
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503191129_052A_L1SGRTBR_2220220.nc) downloaded successfully
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503191308_068A_L1SGRTBR_2220220.nc) downloaded successfully
# ERA5 downloaded - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250319T180351_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250319T180351_20250319T180451_058377_0737EB_57CA.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250328T075558_20250328T075658_058502_073CDD_C19D 20250328
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HH_72_-15_20250328T075558.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HV_72_-15_20250328T075558.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_angle_72_-15_20250328T075558.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\Chart\72_-15\DMI_1302_20250327_72_-15.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\Chart\72_-15\DMI_1302_20250331_72_-15.tif
# Matched for 2025-03-28 04:55:58 to 2025-03-28 10:55:58: 4
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503280537_003D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503280716_019D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503280855_035D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503280944_035A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 downloaded - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250328T075558_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250328T075558_20250328T075658_058502_073CDD_C19D.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250331T180351_20250331T180451_058552_073EF2_D6C0 20250331
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HH_72_-15_20250331T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HV_72_-15_20250331T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_angle_72_-15_20250331T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\Chart\72_-15\DMI_1302_20250404_72_-15.tif
# Matched for 2025-03-31 15:03:51 to 2025-03-31 21:03:51: 0
# Matched for 2025-03-31 12:03:51 to 2025-04-01 00:03:51: 1
# Matched for 2025-03-31 09:03:51 to 2025-04-01 03:03:51: 4
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503310925_040D_L1SGRTBR_2220220.nc) downloaded successfully
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503311015_040A_L1SGRTBR_2220220.nc) downloaded successfully
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503311154_056A_L1SGRTBR_2220220.nc) downloaded successfully
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202503311333_072A_L1SGRTBR_2220220.nc) downloaded successfully
# ERA5 downloaded - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250331T180351_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250331T180351_20250331T180451_058552_073EF2_D6C0.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250409T075558_20250409T075658_058677_074406_E1E9 20250409
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HH_72_-15_20250409T075558.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HV_72_-15_20250409T075558.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_angle_72_-15_20250409T075558.tif
# Matched for 2025-04-09 04:55:58 to 2025-04-09 10:55:58: 5
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504090601_007D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504090740_023D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504090919_039D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504090830_023A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504091009_039A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 downloaded - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250409T075558_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250409T075558_20250409T075658_058677_074406_E1E9.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250412T180351_20250412T180451_058727_07461D_88F7 20250412
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HH_72_-15_20250412T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HV_72_-15_20250412T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_angle_72_-15_20250412T180351.tif
# Matched for 2025-04-12 15:03:51 to 2025-04-12 21:03:51: 0
# Matched for 2025-04-12 12:03:51 to 2025-04-13 00:03:51: 2
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504121218_060A_L1SGRTBR_2220220.nc) downloaded successfully
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504121357_076A_L1SGRTBR_2220220.nc) downloaded successfully
# ERA5 downloaded - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250412T180351_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250412T180351_20250412T180451_058727_07461D_88F7.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250421T075558_20250421T075658_058852_074B32_B428 20250421
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HH_72_-15_20250421T075558.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HV_72_-15_20250421T075558.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_angle_72_-15_20250421T075558.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\Chart\72_-15\DMI_1302_20250423_72_-15.tif
# Matched for 2025-04-21 04:55:58 to 2025-04-21 10:55:58: 5
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504210627_011D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504210805_027D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504210944_043D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504210855_027A_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504211034_043A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 downloaded - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250421T075558_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250421T075558_20250421T075658_058852_074B32_B428.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250424T180351_20250424T180451_058902_074D42_38F1 20250424
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HH_72_-15_20250424T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HV_72_-15_20250424T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_angle_72_-15_20250424T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\Chart\72_-15\DMI_1302_20250428_72_-15.tif
# Matched for 2025-04-24 15:03:51 to 2025-04-24 21:03:51: 0
# Matched for 2025-04-24 12:03:51 to 2025-04-25 00:03:51: 1
# Matched for 2025-04-24 09:03:51 to 2025-04-25 03:03:51: 5
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504241015_048D_L1SGRTBR_2220220.nc) downloaded successfully
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504240926_032A_L1SGRTBR_2220220.nc) downloaded successfully
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504241105_048A_L1SGRTBR_2220220.nc) downloaded successfully
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504241243_064A_L1SGRTBR_2220220.nc) downloaded successfully
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202504250244_208D_L1SGRTBR_2220220.nc) downloaded successfully
# ERA5 downloaded - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250424T180351_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250424T180351_20250424T180451_058902_074D42_38F1.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250503T075558_20250503T075658_059027_07523C_399E 20250503
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HH_72_-15_20250503T075558.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HV_72_-15_20250503T075558.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_angle_72_-15_20250503T075558.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\Chart\72_-15\DMI_1302_20250506_72_-15.tif
# Matched for 2025-05-03 04:55:58 to 2025-05-03 10:55:58: 5
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202505030512_232D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202505030651_015D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202505030830_031D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202505031009_047D_L1SGRTBR_2220220.nc exists, skipping download
# file C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202505030919_031A_L1SGRTBR_2220220.nc exists, skipping download
# ERA5 downloaded - C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\ERA5\72_-15\ERA5_20250503T075558_72_-15.nc
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250503T075558_20250503T075658_059027_07523C_399E.nc
#
# COPERNICUS/S1_GRD/S1A_EW_GRDM_1SDH_20250506T180351_20250506T180451_059077_07543A_1C92 20250506
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HH_72_-15_20250506T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_HV_72_-15_20250506T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\S1\72_-15\S1_angle_72_-15_20250506T180351.tif
# Saved to C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\Chart\72_-15\DMI_1302_20250510_72_-15.tif
# Matched for 2025-05-06 15:03:51 to 2025-05-06 21:03:51: 0
# Matched for 2025-05-06 12:03:51 to 2025-05-07 00:03:51: 1
# Matched for 2025-05-06 09:03:51 to 2025-05-07 03:03:51: 3
# AMSR (C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\AMSR\GW1AM2_202505060950_036A_L1SGRTBR_2220220.nc) downloaded successfully

# %%
combine_to_netcdf(lat0, lon0, time0, sar_id, amsr_files, file_era5, chart_id)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# DONE ==>>  C:\Users\yoko2261\OneDrive - UCB-O365\CAIG\TS\NetCDF\72_-15\S1A_EW_GRDM_1SDH_20250307T180351_20250307T180451_058202_073109_F925.nc

# %%
chart_id
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 'DMI_1302'

# %% [markdown]
# ## Analyze data

# %%
for month in ["01", "02", "03", "04"]: #["10", "11", "12"]:
    center = [lon0, lat0]
    distance = 120000
    extent = get_extent(center, distance, proj)
    #####################################################################
    
    # Create polygon from EPSG:3408 coordinates
    coords = extent.getInfo()['coordinates']
    coords2 = [(xys[0], xys[1]) for xys in coords[0]]
    # poly = Polygon(coords_3408)
    
    # Build GeoDataFrame
    extent_gdf = rectangle_to_gdf(coords2, proj)
    subfolder = f"{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}"
    S1_images = sorted(glob.glob(folder + f"S1\\{subfolder}\\S1_HH_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}_{year}{month}*.tif"))
    chart_images = sorted(glob.glob(folder + f"Chart\\{subfolder}\\*_{year}{month}*_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}.tif"))
    chart_unique = unique_value([os.path.basename(c).split("_")[0] + "_" + os.path.basename(c).split("_")[1] for c in chart_images])
    
    xx = read_tif(folder + f"S1\\{subfolder}\\S1_x_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}.tif")
    yy = read_tif(folder + f"S1\\{subfolder}\\S1_y_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}.tif")
    row, col = xx.shape
    
    N = len(S1_images[:])
    
    array_HH = np.zeros((N, row, col))
    array_HV = np.zeros((N, row, col))
    array_CT = np.zeros((len(chart_unique), N, row, col))
    array_SA = np.zeros((len(chart_unique), N, row, col))
    dates = []
    dates_chart = np.zeros((len(chart_unique), N))
    
    for n in range(0, N):
        S1_file = S1_images[n]
        
        time0 = S1_file[-19:-4] #f.split("_")[-5]
        date0 = time0[:8]
        dates.append(date0)
    
        array_HH[n] = read_tif(S1_file)
        array_HV[n] = read_tif(S1_file.replace("S1_HH", "S1_HV"))

        for c in range(0, len(chart_unique)):
            CT = np.zeros((row, col))
            SA = np.zeros((row, col))
            chart_list = glob.glob(folder + f"Chart\\{subfolder}\\{chart_unique[c]}_{year}{month}*.tif")

            chart_file = find_nearest_chart(os.path.basename(S1_file).split("_")[-1][:-4], chart_list)

            array_chart = read_tif(chart_file)  
        
            chart = pd.read_csv(chart_file.replace(".tif", ".csv"), index_col = 0)
            for poly_id in np.unique(array_chart):
                CT[array_chart == poly_id] = chart.loc[chart['poly_id'] == poly_id, "CT"].mean()
                SA[array_chart == poly_id] = chart.loc[chart['poly_id'] == poly_id, "SA"].mean()

            land_mask = CT <= 0
            CT[land_mask] = np.nan
            SA[land_mask] = np.nan
            
            array_CT[c, n] = CT
            array_SA[c, n] = SA
            dates_chart[c, n] = os.path.basename(chart_file).split("_")[2]

            print(os.path.basename(S1_file), os.path.basename(chart_file))

    ##### Draw CT #####
    fig, ax = plt.subplots(N, 2+len(chart_unique), figsize = (3*(2+len(chart_unique)), 3*N), dpi = 200, sharex = True, sharey = True, num = 1, clear = True)
    plt.subplots_adjust(hspace=0.1, wspace=0.1)
    
    for n in range(0, N):
        # ax[n].pcolormesh(xx, yy, array_HH[n])
        ax[n, 0].imshow(array_HH[n], vmin = -20, vmax = -5, cmap = "gray")
        ax[n, 1].imshow(array_HV[n], vmin = -40, vmax = -20, cmap = "gray")    
        ax[n, 0].annotate("HH", xy=(0.02, 0.02), xycoords='axes fraction', size = 14, va = 'bottom', ha ='left', color = "yellow")
        ax[n, 1].annotate("HV", xy=(0.02, 0.02), xycoords='axes fraction', size = 14, va = 'bottom', ha ='left', color = "yellow")
    
        for k in range(0, len(chart_unique)):
            ax[n, 2+k].imshow(array_CT[k, n], vmin = 0, vmax = 100)
            ax[n, 2+k].annotate(f"CT ({chart_unique[k]})", xy=(0.02, 0.02), xycoords='axes fraction', size = 14, va = 'bottom', ha ='left', color = "b")
        
        for m in range(0, 2+len(chart_unique)):
            ax[n, m].grid(ls = ":", lw = 1.0)        
            if m < 2:
                ax[n, m].annotate(dates[n], xy=(0.02, 0.98), xycoords='axes fraction', size = 14, va = 'top', ha ='left', color = "r")
            else:
                ax[n, m].annotate(int(dates_chart[m-2, n]), xy=(0.02, 0.98), xycoords='axes fraction', size = 14, va = 'top', ha ='left', color = "r")
    
    plt.savefig(folder + f"\\Figure\\CT_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}_{year}{month}.png", bbox_inches = "tight")
    fig.clear()
    plt.close(fig)

    ##### Draw SA #####
    fig, ax = plt.subplots(N, 2+len(chart_unique), figsize = (3*(2+len(chart_unique)), 3*N), dpi = 200, sharex = True, sharey = True, num = 1, clear = True)
    plt.subplots_adjust(hspace=0.1, wspace=0.1)
    
    for n in range(0, N):
        # ax[n].pcolormesh(xx, yy, array_HH[n])
        ax[n, 0].imshow(array_HH[n], vmin = -20, vmax = -5, cmap = "gray")
        ax[n, 1].imshow(array_HV[n], vmin = -40, vmax = -20, cmap = "gray")    
        ax[n, 0].annotate("HH", xy=(0.02, 0.02), xycoords='axes fraction', size = 14, va = 'bottom', ha ='left', color = "yellow")
        ax[n, 1].annotate("HV", xy=(0.02, 0.02), xycoords='axes fraction', size = 14, va = 'bottom', ha ='left', color = "yellow")
    
        for k in range(0, len(chart_unique)):        
            ax[n, 2+k].imshow(array_SA[k, n], vmin = 81, vmax = 98)
            ax[n, 2+k].annotate(f"SA ({chart_unique[k]})", xy=(0.02, 0.02), xycoords='axes fraction', size = 14, va = 'bottom', ha ='left', color = "b")
        
        for m in range(0, 2+len(chart_unique)):
            ax[n, m].grid(ls = ":", lw = 1.0)        
            if m < 2:
                ax[n, m].annotate(dates[n], xy=(0.02, 0.98), xycoords='axes fraction', size = 14, va = 'top', ha ='left', color = "r")
            else:
                ax[n, m].annotate(int(dates_chart[m-2, n]), xy=(0.02, 0.98), xycoords='axes fraction', size = 14, va = 'top', ha ='left', color = "r")
    
    plt.savefig(folder + f"\\Figure\\SA_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}_{year}{month}.png", bbox_inches = "tight")
    fig.clear()
    plt.close(fig)

    print("DONE!")

# %%
fig, ax = plt.subplots(N, 2+len(chart_unique), figsize = (3*(2+len(chart_unique)), 3*N), dpi = 200, sharex = True, sharey = True, num = 1, clear = True)
plt.subplots_adjust(hspace=0.1, wspace=0.1)

for n in range(0, N):
    # ax[n].pcolormesh(xx, yy, array_HH[n])
    ax[n, 0].imshow(array_HH[n], vmin = -20, vmax = -5, cmap = "gray")
    ax[n, 1].imshow(array_HV[n], vmin = -40, vmax = -20, cmap = "gray")    
    ax[n, 0].annotate("HH", xy=(0.02, 0.02), xycoords='axes fraction', size = 14, va = 'bottom', ha ='left', color = "yellow")
    ax[n, 1].annotate("HV", xy=(0.02, 0.02), xycoords='axes fraction', size = 14, va = 'bottom', ha ='left', color = "yellow")

    for k in range(0, len(chart_unique)):
        ax[n, 2+k].imshow(array_CT[k, n], vmin = 0, vmax = 100)
        ax[n, 2+k].annotate(f"CT ({chart_unique[k]})", xy=(0.02, 0.02), xycoords='axes fraction', size = 14, va = 'bottom', ha ='left', color = "b")
    
    for m in range(0, 2+len(chart_unique)):
        ax[n, m].grid(ls = ":", lw = 1.0)        
        if m < 2:
            ax[n, m].annotate(dates[n], xy=(0.02, 0.98), xycoords='axes fraction', size = 14, va = 'top', ha ='left', color = "r")
        else:
            ax[n, m].annotate(int(dates_chart[m-2, n]), xy=(0.02, 0.98), xycoords='axes fraction', size = 14, va = 'top', ha ='left', color = "r")

# plt.savefig(folder + f"\\Figure\\Charts_CT_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}_{year}{month}.png", bbox_inches = "tight")
# fig.clear()
# plt.close(fig)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
fig, ax = plt.subplots(N, 2+len(chart_unique), figsize = (3*(2+len(chart_unique)), 3*N), dpi = 200, sharex = True, sharey = True, num = 1, clear = True)
plt.subplots_adjust(hspace=0.1, wspace=0.1)

for n in range(0, N):
    # ax[n].pcolormesh(xx, yy, array_HH[n])
    ax[n, 0].imshow(array_HH[n], vmin = -20, vmax = -5, cmap = "gray")
    ax[n, 1].imshow(array_HV[n], vmin = -40, vmax = -20, cmap = "gray")    
    ax[n, 0].annotate("HH", xy=(0.02, 0.02), xycoords='axes fraction', size = 14, va = 'bottom', ha ='left', color = "w")
    ax[n, 1].annotate("HV", xy=(0.02, 0.02), xycoords='axes fraction', size = 14, va = 'bottom', ha ='left', color = "w")

    for k in range(0, len(chart_unique)):        
        ax[n, 2+k].imshow(array_SA[k, n], vmin = 81, vmax = 98)
        ax[n, 2+k].annotate(f"SA ({chart_unique[k]})", xy=(0.02, 0.02), xycoords='axes fraction', size = 14, va = 'bottom', ha ='left', color = "w")
    
    for m in range(0, 2+len(chart_unique)):
        ax[n, m].grid(ls = ":", lw = 1.0)        
        if m < 2:
            ax[n, m].annotate(dates[n], xy=(0.02, 0.98), xycoords='axes fraction', size = 14, va = 'top', ha ='left')
        else:
            ax[n, m].annotate(int(dates_chart[m-2, n]), xy=(0.02, 0.98), xycoords='axes fraction', size = 14, va = 'top', ha ='left', color = "w")

# plt.savefig(folder + f"\\Figure\\Charts_{str(int(lat0)).zfill(2)}_{str(int(lon0)).zfill(3)}_{year}{month}.png", bbox_inches = "tight")
# fig.clear()
# plt.close(fig)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
